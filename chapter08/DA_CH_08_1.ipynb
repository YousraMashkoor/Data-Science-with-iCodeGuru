# %% [markdown]
# ##  The Basic Probability Formula, Computing Expected Values,
# ##   Frequency, Events and Their Complements.

# %%
The Basic Probability Formula, 
chance of happening; likelihood of an event occuring
1- single probability of a coin , head or tail == 1/2

# %%
0 -- 1 want to say 0.2 instead of 20% or 1/5 

probability == P(A)==preferred outcome/all possible outcome

probabilty of divisible by 3 is 2/6 and actual is 1/6

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
two independent event occuring at the same time
P(A).P(B)  #product of probability of each event

probability of getting ace and spade ? is product

# %%
types == diamond,  heart, club, spade,  total card-52,
 4-each and all,   2-colors == black and red

# %%
Computing Expected Values:
expect the value if we run work many times
Toss a coin many times, toss 20 times and 20 outcome
P(A)== number of successful trial/total trials
Expected(A) == P(A)xnumber of trials == 0.25x20 ==5

# %%
The expected value (EV) is an anticipated value for an investment at some point
 in the future. In statistics and probability analysis, the expected value is 
 calculated by multiplying each of the possible outcomes by the likelihood 
 each outcome will occur and then summing all of those values.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
expected values in a numerical way
sample space A = 10 points, B==20 points, C==100 points
numerical outcome == P(A).A + P(B).B + P(C).C
example hitting the board with three circle =  0.5 , 0.4, 0.1
expected value in this case is 0.5x10 + 0.4x20 + 0.1x100 == 23
what is expected value of an evenet is based on past data. 
interval not specific values due to uncertainity that future brings: like weather rain is likely interval
this is prediction and can be estimated by frequency ??????

# %%
Frequency:
consider two dice of six sided, 6 options of each
6x6 36 total outcome for two rolls
chance of getting P(7)  == 6/36

bar chart or plot of any single column is a good example.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
Events and Their Complements.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
all the possible outcome always one == P(A)+P(B)+P(C)==1

coin head+tail ==1
1/6+1/6+1/6+1/6+1/6+1/6==1
we are double counting some of the possible outcomes like frequency in bar plot
